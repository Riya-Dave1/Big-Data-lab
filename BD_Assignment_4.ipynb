# %% [markdown]
# <a href="https://colab.research.google.com/github/Riya-Dave1/Big-Data-lab/blob/main/BD_Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Name: Riya Dave
# ##ID: 202318011

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=1edf4b1e6a3f29ff14d88121a6baf53ffbd4b533f1b93a89f5ef8e59c8d32abc
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("RDD and DataFrame Manipulation") \
    .getOrCreate()

# %%
rdd = spark.sparkContext.textFile("/content/text8")

# %%
type(rdd)
# Out:
# pyspark.rdd.RDD

# %%
import numpy as np

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("RDD Task 1") \
    .getOrCreate()

# Generate 100 random numbers in the range 0 to 10 using numpy
np.random.seed(10)  # Set seed for reproducibility
random_numbers = np.random.randint(0, 11, size=100)
print(random_numbers)

# Create an RDD using the parallelize function
rdd = spark.sparkContext.parallelize(random_numbers)

# Calculate the frequency of each number (0 - 10) using appropriate function of RDD
frequency_counts = rdd.map(lambda x: (x, 1)).reduceByKey(lambda a, b: a + b).sortByKey()

# Collect the results
results = frequency_counts.collect()

# Print the results
print("Number\tFrequency")
for number, frequency in results:
    print(f"{number}\t{frequency}")

# Stop the SparkSession
spark.stop()
# Out:
# [ 9  4  0  1  9  0  1 10  8  9  0 10  8  6  4  3  0  4  6  8 10  1  8  4
#   1  3  6  5  3  9  6  9  1  9  4  2  6  7  8 10  8  9  2  0  6  7  8  1
#   7  1  4 10  0  8  5  4  7  8  8  2  6  2  8  8  6  6  5 10  6  0  0  6
#   9  1  8 10  9  1  2  8  9  9  5  0  2  7  3  0  4  2  0  3  3  1  2  5
#   9  0 10  1]
# Number	Frequency
# 0	12
# 1	11
# 2	8
# 3	6
# 4	8
# 5	5
# 6	11
# 7	5
# 8	14
# 9	12
# 10	8

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("RDD Task 2") \
    .getOrCreate()

# Create an RDD using the text8 dataset
text_rdd = spark.sparkContext.textFile("/content/text8.unknown")

# Split each line into words and flatten the list of words
words_rdd = text_rdd.flatMap(lambda line: line.split())

# Calculate the frequency of each word
word_frequencies = words_rdd.map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)

# Filter the RDD to get the frequencies of words containing the letter 'a'
words_with_a_frequencies = word_frequencies.filter(lambda pair: 'a' in pair[0])

# Collect and print the results
results = words_with_a_frequencies.collect()
for word, frequency in results:
    print(f"Word: {word}\tFrequency: {frequency}")

# Stop the SparkSession
spark.stop()
# Out:
# Streaming output truncated to the last 5000 lines.
# Word: tuhaj	Frequency: 1
# Word: leaseholders	Frequency: 1
# Word: pilavtsi	Frequency: 1
# Word: awce	Frequency: 1
# Word: butka	Frequency: 1
# Word: vasilyevna	Frequency: 1
# Word: yeltsina	Frequency: 1
# Word: majoring	Frequency: 2
# Word: uraltyazhtrubstroi	Frequency: 1
# Word: ligachev	Frequency: 2
# Word: dacha	Frequency: 1
# Word: stanislau	Frequency: 1
# Word: apparatchiks	Frequency: 1
# Word: gennadiy	Frequency: 1
# Word: chubais	Frequency: 1
# Word: ruslan	Frequency: 3
# Word: advertized	Frequency: 1
# Word: diatchenko	Frequency: 1
# Word: korzhakov	Frequency: 3
# Word: abramovich	Frequency: 6
# Word: talbott	Frequency: 3
# Word: beslan	Frequency: 4
# Word: discraded	Frequency: 1
# Word: gazprom	Frequency: 1
# Word: cucinotta	Frequency: 1
# Word: starcrossed	Frequency: 2
# Word: kantrowitz	Frequency: 1
# Word: weathermakers	Frequency: 1
# Word: powersat	Frequency: 1
# Word: moonwar	Frequency: 1
# Word: okinawans	Frequency: 2
# Word: toyama	Frequency: 1
# Word: naha	Frequency: 1
# Word: habu	Frequency: 1
# Word: inexorable	Frequency: 1
# Word: neutralising	Frequency: 1
# Word: sakishima	Frequency: 1
# Word: kami	Frequency: 1
# Word: shima	Frequency: 1
# Word: tennozan	Frequency: 1
# Word: facetiously	Frequency: 1
# Word: balneum	Frequency: 1
# Word: cheesecake	Frequency: 1
# Word: cardenal	Frequency: 1
# Word: moncada	Frequency: 5
# Word: khadem	Frequency: 1
# Word: barbagias	Frequency: 1
# Word: ollolai	Frequency: 1
# Word: gavoi	Frequency: 1
# Word: oliena	Frequency: 1
# Word: cannonau	Frequency: 1
# Word: fancar	Frequency: 1
# Word: daunted	Frequency: 1
# Word: wilhelmshaven	Frequency: 1
# Word: bombload	Frequency: 1
# Word: airworthiness	Frequency: 1
# Word: dfa	Frequency: 1
# Word: bathyscaphe	Frequency: 3
# Word: bathysphere	Frequency: 1
# Word: electromagnets	Frequency: 3
# Word: bathyscaphes	Frequency: 1
# Word: touraine	Frequency: 2
# Word: countermarched	Frequency: 1
# Word: preveza	Frequency: 1
# Word: planthe	Frequency: 1
# Word: liburnian	Frequency: 1
# Word: ballistae	Frequency: 1
# Word: danio	Frequency: 11
# Word: danios	Frequency: 10
# Word: zebras	Frequency: 2
# Word: segregate	Frequency: 1
# Word: barilius	Frequency: 1
# Word: chapalio	Frequency: 1
# Word: nuria	Frequency: 1
# Word: perilampus	Frequency: 1
# Word: danionins	Frequency: 1
# Word: adowa	Frequency: 3
# Word: adwa	Frequency: 2
# Word: tigray	Frequency: 2
# Word: makonnen	Frequency: 1
# Word: visualised	Frequency: 1
# Word: ferromagnetic	Frequency: 6
# Word: credentialed	Frequency: 1
# Word: skeptikcal	Frequency: 1
# Word: allaby	Frequency: 1
# Word: sourcewatch	Frequency: 2
# Word: bandanaira	Frequency: 1
# Word: neira	Frequency: 2
# Word: selamon	Frequency: 1
# Word: waer	Frequency: 1
# Word: syahrir	Frequency: 1
# Word: rozengain	Frequency: 1
# Word: nailaka	Frequency: 1
# Word: manuk	Frequency: 1
# Word: karaka	Frequency: 1
# Word: manukang	Frequency: 1
# Word: bandas	Frequency: 1
# Word: ambonese	Frequency: 4
# Word: tetaruga	Frequency: 1
# Word: tartaruga	Frequency: 1
# Word: gargontong	Frequency: 1
# Word: elat	Frequency: 1
# Word: shadypalm	Frequency: 1
# Word: maranta	Frequency: 1
# Word: anz	Frequency: 17
# Word: backo	Frequency: 2
# Word: traveland	Frequency: 1
# Word: auscel	Frequency: 1
# Word: karmichael	Frequency: 1
# Word: energyaustralia	Frequency: 2
# Word: berrigan	Frequency: 1
# Word: civoniceva	Frequency: 1
# Word: rothmans	Frequency: 3
# Word: akermanis	Frequency: 4
# Word: mcrae	Frequency: 1
# Word: szarlejski	Frequency: 1
# Word: ukasz	Frequency: 1
# Word: kostka	Frequency: 1
# Word: whitewash	Frequency: 6
# Word: inla	Frequency: 1
# Word: showband	Frequency: 1
# Word: blackest	Frequency: 3
# Word: achtum	Frequency: 1
# Word: rhumba	Frequency: 1
# Word: clave	Frequency: 1
# Word: hambone	Frequency: 2
# Word: maracas	Frequency: 2
# Word: mannish	Frequency: 1
# Word: infuriate	Frequency: 1
# Word: sweaty	Frequency: 1
# Word: moochas	Frequency: 1
# Word: arisztid	Frequency: 1
# Word: todeskarawane	Frequency: 1
# Word: typecasting	Frequency: 1
# Word: typecast	Frequency: 3
# Word: ninotchka	Frequency: 1
# Word: katzman	Frequency: 1
# Word: glenda	Frequency: 1
# Word: chiropractor	Frequency: 1
# Word: vampira	Frequency: 1
# Word: manservant	Frequency: 1
# Word: onrandom	Frequency: 1
# Word: taphysique	Frequency: 1
# Word: berryparadox	Frequency: 1
# Word: chiatin	Frequency: 1
# Word: courmayer	Frequency: 1
# Word: meenlinna	Frequency: 2
# Word: tavastehus	Frequency: 2
# Word: zakopane	Frequency: 1
# Word: antholz	Frequency: 5
# Word: anterselva	Frequency: 5
# Word: khanty	Frequency: 3
# Word: pyeongchang	Frequency: 1
# Word: olena	Frequency: 4
# Word: zubrilova	Frequency: 4
# Word: breatharian	Frequency: 9
# Word: breatharians	Frequency: 4
# Word: prahlad	Frequency: 4
# Word: ahmedabad	Frequency: 1
# Word: somnambulism	Frequency: 1
# Word: hira	Frequency: 2
# Word: lagan	Frequency: 3
# Word: farset	Frequency: 4
# Word: fearsaid	Frequency: 1
# Word: languishes	Frequency: 1
# Word: laganside	Frequency: 2
# Word: neagh	Frequency: 2
# Word: linenhall	Frequency: 1
# Word: shankill	Frequency: 2
# Word: glencairn	Frequency: 2
# Word: ardoyne	Frequency: 3
# Word: rathcoole	Frequency: 2
# Word: mlas	Frequency: 3
# Word: citybeat	Frequency: 2
# Word: bmua	Frequency: 1
# Word: andersonstown	Frequency: 1
# Word: ballymurphy	Frequency: 1
# Word: braniel	Frequency: 1
# Word: cregagh	Frequency: 1
# Word: ravenhill	Frequency: 1
# Word: woodvale	Frequency: 1
# Word: flaking	Frequency: 1
# Word: polygamist	Frequency: 7
# Word: alimony	Frequency: 2
# Word: zina	Frequency: 1
# Word: greenleaf	Frequency: 1
# Word: rhoda	Frequency: 1
# Word: whitmarsh	Frequency: 1
# Word: malin	Frequency: 1
# Word: sagers	Frequency: 1
# Word: tapfield	Frequency: 1
# Word: bergera	Frequency: 1
# Word: canna	Frequency: 1
# Word: sae	Frequency: 1
# Word: thankit	Frequency: 1
# Word: aboon	Frequency: 2
# Word: thairm	Frequency: 1
# Word: groaning	Frequency: 2
# Word: hindmaist	Frequency: 1
# Word: guidman	Frequency: 1
# Word: bethankit	Frequency: 1
# Word: ragout	Frequency: 1
# Word: staw	Frequency: 1
# Word: taps	Frequency: 2
# Word: lassies	Frequency: 3
# Word: laddies	Frequency: 1
# Word: annoyingly	Frequency: 2
# Word: westway	Frequency: 1
# Word: reacquaintance	Frequency: 1
# Word: megatop	Frequency: 1
# Word: barnato	Frequency: 3
# Word: steeplechaser	Frequency: 1
# Word: fastback	Frequency: 1
# Word: brooklands	Frequency: 3
# Word: phaeton	Frequency: 1
# Word: qualifier	Frequency: 3
# Word: cephalochordata	Frequency: 2
# Word: hemichordates	Frequency: 1
# Word: craniata	Frequency: 1
# Word: gnathostomata	Frequency: 1
# Word: jawed	Frequency: 2
# Word: sarcopterygii	Frequency: 1
# Word: actinistia	Frequency: 1
# Word: tetrapoda	Frequency: 1
# Word: synapsida	Frequency: 1
# Word: anapsida	Frequency: 1
# Word: diapsida	Frequency: 1
# Word: tuatara	Frequency: 1
# Word: gharials	Frequency: 1
# Word: nutcracker	Frequency: 5
# Word: aileen	Frequency: 2
# Word: galliano	Frequency: 2
# Word: spokeswoman	Frequency: 2
# Word: janggi	Frequency: 1
# Word: expoloitable	Frequency: 1
# Word: zugzwang	Frequency: 1
# Word: tablebases	Frequency: 1
# Word: overemphasis	Frequency: 1
# Word: chaturanga	Frequency: 2
# Word: chatrang	Frequency: 1
# Word: ajedrez	Frequency: 1
# Word: zatrikion	Frequency: 1
# Word: alfinus	Frequency: 1
# Word: alfferza	Frequency: 1
# Word: anderssen	Frequency: 3
# Word: kasimdzhanov	Frequency: 1
# Word: shawshank	Frequency: 1
# Word: chessbase	Frequency: 2
# Word: playchess	Frequency: 1
# Word: instantchess	Frequency: 1
# Word: gameknot	Frequency: 1
# Word: highergames	Frequency: 1
# Word: stadacona	Frequency: 3
# Word: donnacona	Frequency: 1
# Word: anse	Frequency: 1
# Word: cumulatively	Frequency: 1
# Word: cincinnatians	Frequency: 1
# Word: hanwell	Frequency: 1
# Word: karno	Frequency: 3
# Word: sneaking	Frequency: 1
# Word: choreography	Frequency: 3
# Word: oona	Frequency: 3
# Word: vaud	Frequency: 1
# Word: caricaturist	Frequency: 1
# Word: floorwalker	Frequency: 1
# Word: pawnshop	Frequency: 1
# Word: purviance	Frequency: 1
# Word: kiera	Frequency: 1
# Word: classicmovies	Frequency: 1
# Word: starrie	Frequency: 1
# Word: steganography	Frequency: 4
# Word: cryptogram	Frequency: 1
# Word: polyalphabetic	Frequency: 6
# Word: cardan	Frequency: 1
# Word: hellman	Frequency: 6
# Word: adleman	Frequency: 2
# Word: cryptanalyst	Frequency: 9
# Word: zimmermann	Frequency: 3
# Word: platitudes	Frequency: 1
# Word: particularism	Frequency: 2
# Word: particularists	Frequency: 1
# Word: inculcation	Frequency: 1
# Word: provably	Frequency: 3
# Word: colorable	Frequency: 1
# Word: downplays	Frequency: 3
# Word: myanma	Frequency: 1
# Word: nationmaster	Frequency: 2
# Word: abkazia	Frequency: 1
# Word: cornwallflag	Frequency: 1
# Word: populationdata	Frequency: 1
# Word: kopenhagen	Frequency: 1
# Word: bjerregaard	Frequency: 1
# Word: asmus	Frequency: 1
# Word: kjeldgaard	Frequency: 1
# Word: labout	Frequency: 1
# Word: forkbeard	Frequency: 1
# Word: havn	Frequency: 1
# Word: trainlines	Frequency: 1
# Word: amager	Frequency: 2
# Word: landskrona	Frequency: 1
# Word: enghave	Frequency: 1
# Word: vestamager	Frequency: 1
# Word: plads	Frequency: 1
# Word: parken	Frequency: 1
# Word: cobras	Frequency: 1
# Word: christiansborg	Frequency: 2
# Word: amalienborg	Frequency: 1
# Word: arken	Frequency: 1
# Word: kastellet	Frequency: 1
# Word: brandes	Frequency: 1
# Word: jacobsen	Frequency: 2
# Word: aok	Frequency: 1
# Word: enumerative	Frequency: 7
# Word: matroid	Frequency: 3
# Word: extremal	Frequency: 7
# Word: combinatorialists	Frequency: 1
# Word: algebraization	Frequency: 1
# Word: calx	Frequency: 2
# Word: calcis	Frequency: 1
# Word: manjula	Frequency: 1
# Word: jyeshtadeva	Frequency: 1
# Word: newtoncalculus	Frequency: 1
# Word: hyperreal	Frequency: 1
# Word: loftsgaarden	Frequency: 1
# Word: spivak	Frequency: 1
# Word: stroyan	Frequency: 1
# Word: faraz	Frequency: 1
# Word: sangamagramma	Frequency: 1
# Word: transactive	Frequency: 1
# Word: intrapersonal	Frequency: 1
# Word: communcation	Frequency: 1
# Word: jakobson	Frequency: 4
# Word: communicare	Frequency: 1
# Word: smartmobbing	Frequency: 1
# Word: indiscrimination	Frequency: 1
# Word: semaphores	Frequency: 1
# Word: classicus	Frequency: 2
# Word: metacharatte	Frequency: 1
# Word: nomisma	Frequency: 1
# Word: humaniores	Frequency: 2
# Word: tartu	Frequency: 1
# Word: linguae	Frequency: 1
# Word: describable	Frequency: 1
# Word: astrochemistry	Frequency: 2
# Word: paramagnetic	Frequency: 1
# Word: biomacromolecules	Frequency: 1
# Word: alkemie	Frequency: 1
# Word: mashiach	Frequency: 1
# Word: messias	Frequency: 1
# Word: essenian	Frequency: 1
# Word: rosicrucian	Frequency: 3
# Word: passionless	Frequency: 2
# Word: cheapens	Frequency: 1
# Word: nunataks	Frequency: 1
# Word: batholites	Frequency: 1
# Word: torngat	Frequency: 1
# Word: fuca	Frequency: 2
# Word: coola	Frequency: 1
# Word: saskatchewann	Frequency: 1
# Word: ofpopulation	Frequency: 1
# Word: eckankar	Frequency: 1
# Word: layton	Frequency: 2
# Word: asdb	Frequency: 2
# Word: minurca	Frequency: 4
# Word: untaet	Frequency: 1
# Word: rideau	Frequency: 3
# Word: encana	Frequency: 2
# Word: barrick	Frequency: 1
# Word: regionalism	Frequency: 2
# Word: multifaceted	Frequency: 2
# Word: skytrain	Frequency: 1
# Word: welland	Frequency: 5
# Word: cancour	Frequency: 1
# Word: paralled	Frequency: 1
# Word: proceduralism	Frequency: 1
# Word: unanimity	Frequency: 4
# Word: simonianism	Frequency: 1
# Word: montanism	Frequency: 1
# Word: swedenborgian	Frequency: 1
# Word: mithraism	Frequency: 1
# Word: dechristianisation	Frequency: 1
# Word: pelikan	Frequency: 1
# Word: chrestiani	Frequency: 1
# Word: fau	Frequency: 1
# Word: godman	Frequency: 1
# Word: wikichristian	Frequency: 2
# Word: superscalar	Frequency: 27
# Word: parallelism	Frequency: 13
# Word: octal	Frequency: 1
# Word: widecharacter	Frequency: 1
# Word: multicharacter	Frequency: 1
# Word: mechatronics	Frequency: 2
# Word: avaya	Frequency: 1
# Word: varian	Frequency: 1
# Word: consortia	Frequency: 1
# Word: naire	Frequency: 1
# Word: actuelle	Frequency: 1
# Word: transistorized	Frequency: 1
# Word: microprogram	Frequency: 3
# Word: isas	Frequency: 3
# Word: rewritable	Frequency: 1
# Word: dissipation	Frequency: 6
# Word: subscalar	Frequency: 6
# Word: artchitectures	Frequency: 1
# Word: xscale	Frequency: 1
# Word: caro	Frequency: 2
# Word: fissipedia	Frequency: 1
# Word: arctoidea	Frequency: 1
# Word: ailurus	Frequency: 2
# Word: musteloidea	Frequency: 1
# Word: superfamilies	Frequency: 2
# Word: caniforms	Frequency: 3
# Word: secondairy	Frequency: 1
# Word: herpestidae	Frequency: 3
# Word: nandinia	Frequency: 1
# Word: miacidae	Frequency: 3
# Word: nimravids	Frequency: 1
# Word: amphicyonids	Frequency: 1
# Word: creodonta	Frequency: 1
# Word: ferae	Frequency: 1
# Word: nandiniidae	Frequency: 1
# Word: viverridae	Frequency: 1
# Word: beardogs	Frequency: 1
# Word: mephitidae	Frequency: 1
# Word: cacique	Frequency: 3
# Word: muisca	Frequency: 3
# Word: chibcha	Frequency: 4
# Word: bastidas	Frequency: 1
# Word: urab	Frequency: 3
# Word: karib	Frequency: 1
# Word: colombians	Frequency: 7
# Word: farc	Frequency: 24
# Word: autodefensas	Frequency: 1
# Word: unidas	Frequency: 1
# Word: pastrana	Frequency: 13
# Word: arango	Frequency: 3
# Word: providencia	Frequency: 6
# Word: ilanos	Frequency: 1
# Word: colombiano	Frequency: 2
# Word: cauca	Frequency: 10
# Word: cristobal	Frequency: 7
# Word: orinoquia	Frequency: 2
# Word: rivality	Frequency: 1
# Word: manizales	Frequency: 2
# Word: importants	Frequency: 1
# Word: estrellas	Frequency: 1
# Word: sucursal	Frequency: 1
# Word: colombias	Frequency: 1
# Word: heroica	Frequency: 1
# Word: querendona	Frequency: 1
# Word: trasnochadora	Frequency: 1
# Word: morena	Frequency: 1
# Word: bucaramanga	Frequency: 2
# Word: abiertas	Frequency: 1
# Word: pasto	Frequency: 1
# Word: sorpresa	Frequency: 1
# Word: milagro	Frequency: 1
# Word: villavicencio	Frequency: 1
# Word: vallenato	Frequency: 2
# Word: revaluation	Frequency: 1
# Word: primarliy	Frequency: 1
# Word: pizzitola	Frequency: 1
# Word: talentless	Frequency: 1
# Word: swanberg	Frequency: 1
# Word: aalberg	Frequency: 1
# Word: roared	Frequency: 1
# Word: goddamned	Frequency: 1
# Word: nasaw	Frequency: 4
# Word: ravecentral	Frequency: 1
# Word: ayylu	Frequency: 1
# Word: hamming	Frequency: 1
# Word: goppa	Frequency: 1
# Word: gallager	Frequency: 1
# Word: cheirogaleoidea	Frequency: 2
# Word: cheirogaleus	Frequency: 8
# Word: adipicaudatus	Frequency: 1
# Word: lehilahytsara	Frequency: 1
# Word: masoala	Frequency: 1
# Word: pariente	Frequency: 1
# Word: parienti	Frequency: 1
# Word: callitrichinae	Frequency: 4
# Word: hapalinae	Frequency: 1
# Word: cebidae	Frequency: 5
# Word: marmosets	Frequency: 3
# Word: callitrichines	Frequency: 2
# Word: saguinus	Frequency: 37
# Word: polyandrous	Frequency: 1
# Word: generalisation	Frequency: 2
# Word: callithrix	Frequency: 53
# Word: jacchus	Frequency: 2
# Word: penicillata	Frequency: 2
# Word: aurita	Frequency: 2
# Word: acariensis	Frequency: 1
# Word: manicore	Frequency: 1
# Word: marcai	Frequency: 2
# Word: humeralifera	Frequency: 2
# Word: saterei	Frequency: 1
# Word: roosmalens	Frequency: 1
# Word: callibella	Frequency: 2
# Word: cebuella	Frequency: 2
# Word: chrysomelas	Frequency: 2
# Word: superagui	Frequency: 2
# Word: graells	Frequency: 2
# Word: melanoleucus	Frequency: 2
# Word: pileatus	Frequency: 2
# Word: labiatus	Frequency: 2
# Word: albifrons	Frequency: 1
# Word: olivaceus	Frequency: 1
# Word: xanthosternos	Frequency: 1
# Word: saimiriinae	Frequency: 1
# Word: saimiri	Frequency: 6
# Word: elasmobranchii	Frequency: 1
# Word: roughsharks	Frequency: 1
# Word: groundsharks	Frequency: 1
# Word: houndsharks	Frequency: 1
# Word: catsharks	Frequency: 1
# Word: lamniformes	Frequency: 2
# Word: megamouth	Frequency: 6
# Word: ovoviviparous	Frequency: 1
# Word: megalodon	Frequency: 3
# Word: carcharodon	Frequency: 1
# Word: holocephali	Frequency: 5
# Word: epigonal	Frequency: 1
# Word: spiracle	Frequency: 1
# Word: placoid	Frequency: 1
# Word: atherion	Frequency: 1
# Word: lapp	Frequency: 1
# Word: laponica	Frequency: 1
# Word: physalis	Frequency: 2
# Word: amno	Frequency: 1
# Word: ramis	Frequency: 1
# Word: glabris	Frequency: 1
# Word: dentoserratis	Frequency: 1
# Word: sensical	Frequency: 1
# Word: matriculation	Frequency: 2
# Word: linnag	Frequency: 1
# Word: avaricious	Frequency: 1
# Word: kalm	Frequency: 1
# Word: solander	Frequency: 1
# Word: hawksbeard	Frequency: 1
# Word: hawkbit	Frequency: 1
# Word: dryander	Frequency: 1
# Word: hasselquist	Frequency: 1
# Word: taxidermy	Frequency: 1
# Word: stratigraphic	Frequency: 4
# Word: seashells	Frequency: 2
# Word: megatheria	Frequency: 1
# Word: detestation	Frequency: 1
# Word: chagas	Frequency: 1
# Word: psychobiological	Frequency: 1
# Word: maer	Frequency: 2
# Word: darwins	Frequency: 1
# Word: cirripedia	Frequency: 3
# Word: forestalled	Frequency: 1
# Word: perpetuation	Frequency: 2
# Word: understatement	Frequency: 2
# Word: paralysing	Frequency: 1
# Word: stigmatised	Frequency: 1
# Word: lepadidae	Frequency: 2
# Word: pedunculated	Frequency: 2
# Word: verrucidae	Frequency: 1
# Word: radick	Frequency: 1
# Word: aboutdarwin	Frequency: 1
# Word: seaborne	Frequency: 1
# Word: cuspate	Frequency: 1
# Word: eustatic	Frequency: 3
# Word: catatonic	Frequency: 10
# Word: hyperactive	Frequency: 5
# Word: beringia	Frequency: 1
# Word: sahul	Frequency: 2
# Word: cosmographie	Frequency: 1
# Word: asthenosphere	Frequency: 1
# Word: ramblers	Frequency: 1
# Word: zandt	Frequency: 1
# Word: maybelle	Frequency: 4
# Word: skaggs	Frequency: 3
# Word: wynonna	Frequency: 2
# Word: acuff	Frequency: 1
# Word: cheatin	Frequency: 1
# Word: faron	Frequency: 1
# Word: baillie	Frequency: 1
# Word: janie	Frequency: 1
# Word: kershaw	Frequency: 1
# Word: krauss	Frequency: 1
# Word: danni	Frequency: 1
# Word: mandrell	Frequency: 1
# Word: lila	Frequency: 2
# Word: lucinda	Frequency: 1
# Word: cornball	Frequency: 1
# Word: hayride	Frequency: 1
# Word: startpage	Frequency: 1
# Word: wherewithal	Frequency: 1
# Word: bankrolling	Frequency: 1
# Word: demilitarization	Frequency: 2
# Word: clamored	Frequency: 1
# Word: wilsonian	Frequency: 1
# Word: unravaged	Frequency: 1
# Word: mahabad	Frequency: 1
# Word: startlingly	Frequency: 1
# Word: isolationists	Frequency: 1
# Word: mastny	Frequency: 1
# Word: lagash	Frequency: 1
# Word: fetha	Frequency: 2
# Word: sarsa	Frequency: 1
# Word: republicae	Frequency: 1
# Word: statuti	Frequency: 1
# Word: comunali	Frequency: 1
# Word: originalism	Frequency: 1
# Word: chaoswiki	Frequency: 1
# Word: snatching	Frequency: 1
# Word: trespasser	Frequency: 2
# Word: countermanded	Frequency: 1
# Word: pluralistic	Frequency: 3
# Word: pleadings	Frequency: 1
# Word: urtheilskraft	Frequency: 1
# Word: zoonomia	Frequency: 1
# Word: evolvability	Frequency: 1
# Word: musicological	Frequency: 1
# Word: internacional	Frequency: 1
# Word: seanaid	Frequency: 1
# Word: artificiality	Frequency: 1
# Word: loglangs	Frequency: 1
# Word: auxlangs	Frequency: 1
# Word: ials	Frequency: 2
# Word: artlangs	Frequency: 3
# Word: armond	Frequency: 1
# Word: conlangers	Frequency: 1
# Word: cratylus	Frequency: 1
# Word: ignota	Frequency: 1
# Word: hildegard	Frequency: 3
# Word: vulgari	Frequency: 1
# Word: lullian	Frequency: 1
# Word: horapollo	Frequency: 1
# Word: polygraphia	Frequency: 1
# Word: dalgarno	Frequency: 1
# Word: charact	Frequency: 1
# Word: faiguet	Frequency: 1
# Word: couturat	Frequency: 1
# Word: leau	Frequency: 1
# Word: pantagruel	Frequency: 1
# Word: conlanger	Frequency: 2
# Word: metalanguage	Frequency: 1
# Word: cabengo	Frequency: 1
# Word: uglossia	Frequency: 1
# Word: kutjarawiki	Frequency: 1
# Word: conlanging	Frequency: 2
# Word: conlangwiki	Frequency: 1
# Word: frathwiki	Frequency: 1
# Word: alphagrip	Frequency: 1
# Word: foldable	Frequency: 1
# Word: altgr	Frequency: 1
# Word: colemak	Frequency: 1
# Word: wearable	Frequency: 7
# Word: quadrans	Frequency: 1
# Word: librae	Frequency: 1
# Word: schickard	Frequency: 2
# Word: reprogrammed	Frequency: 2
# Word: edsac	Frequency: 2
# Word: csirac	Frequency: 2
# Word: sram	Frequency: 1
# Word: arpa	Frequency: 2
# Word: carbonless	Frequency: 1
# Word: minilab	Frequency: 1
# Word: steganographically	Frequency: 1
# Word: interchangably	Frequency: 2
# Word: allotting	Frequency: 1
# Word: internationalism	Frequency: 1
# Word: reassessed	Frequency: 1
# Word: dahrendorf	Frequency: 1
# Word: alinsky	Frequency: 1
# Word: hoxhaism	Frequency: 1
# Word: phane	Frequency: 2
# Word: paczkowski	Frequency: 1
# Word: bartosek	Frequency: 1
# Word: margolin	Frequency: 1
# Word: schwarzbuch	Frequency: 1
# Word: mercantilist	Frequency: 2
# Word: salomone	Frequency: 1
# Word: disclaims	Frequency: 1
# Word: validators	Frequency: 1
# Word: sharer	Frequency: 1
# Word: criminalize	Frequency: 1
# Word: fca	Frequency: 1
# Word: ctea	Frequency: 1
# Word: mpaa	Frequency: 3
# Word: cybersafe	Frequency: 1
# Word: waive	Frequency: 3
# Word: mortgaged	Frequency: 1
# Word: watermarking	Frequency: 1
# Word: valenti	Frequency: 1
# Word: ghosemajumder	Frequency: 1
# Word: babbington	Frequency: 1
# Word: hideaki	Frequency: 1
# Word: infoanarchy	Frequency: 1
# Word: frischmann	Frequency: 1
# Word: moylan	Frequency: 1
# Word: flowchart	Frequency: 2
# Word: catal	Frequency: 13
# Word: valenci	Frequency: 3
# Word: comarques	Frequency: 1
# Word: llitera	Frequency: 1
# Word: cinca	Frequency: 1
# Word: alguer	Frequency: 3
# Word: valenciana	Frequency: 4
# Word: balear	Frequency: 2
# Word: balears	Frequency: 1
# Word: euromosaic	Frequency: 2
# Word: catalanes	Frequency: 1
# Word: languagein	Frequency: 1
# Word: fontanals	Frequency: 1
# Word: consonatic	Frequency: 2
# Word: inchoative	Frequency: 2
# Word: isca	Frequency: 1
# Word: proparoxiton	Frequency: 2
# Word: mirall	Frequency: 1
# Word: llengua	Frequency: 4
# Word: valencians	Frequency: 2
# Word: besal	Frequency: 1
# Word: muntaner	Frequency: 1
# Word: troubadoresque	Frequency: 1
# Word: renaixen	Frequency: 1
# Word: sneaked	Frequency: 1
# Word: plau	Frequency: 1
# Word: aquesta	Frequency: 1
# Word: quant	Frequency: 2
# Word: bany	Frequency: 1
# Word: lavabo	Frequency: 1
# Word: estrangers	Frequency: 1
# Word: ibarz	Frequency: 3
# Word: departament	Frequency: 1
# Word: allioli	Frequency: 1
# Word: diccionari	Frequency: 3
# Word: dacco	Frequency: 1
# Word: vilaweb	Frequency: 1
# Word: overalls	Frequency: 2
# Word: bespectacled	Frequency: 1
# Word: freakish	Frequency: 1
# Word: doberman	Frequency: 1
# Word: scioscia	Frequency: 2
# Word: amadopolis	Frequency: 1
# Word: onassis	Frequency: 1
# Word: performable	Frequency: 1
# Word: notating	Frequency: 1
# Word: drang	Frequency: 1
# Word: emotionalism	Frequency: 2
# Word: italianate	Frequency: 2
# Word: coradin	Frequency: 1
# Word: idiomatically	Frequency: 1
# Word: figuration	Frequency: 2
# Word: examplars	Frequency: 1
# Word: flatward	Frequency: 1
# Word: consonance	Frequency: 6
# Word: guobiao	Frequency: 2
# Word: mojibake	Frequency: 1
# Word: mismap	Frequency: 1
# Word: langauges	Frequency: 1
# Word: erases	Frequency: 2
# Word: interpretable	Frequency: 3
# Word: trigonally	Frequency: 4
# Word: chaoite	Frequency: 1
# Word: nanorods	Frequency: 4
# Word: graphitic	Frequency: 2
# Word: sublimates	Frequency: 3
# Word: charbone	Frequency: 1
# Word: graphites	Frequency: 1
# Word: unnoticeable	Frequency: 1
# Word: heptagons	Frequency: 1
# Word: methanoic	Frequency: 2
# Word: haemoglobin	Frequency: 1
# Word: carbides	Frequency: 3
# Word: abnormaly	Frequency: 1
# Word: lethally	Frequency: 1
# Word: zazula	Frequency: 1
# Word: nonmetals	Frequency: 2
# Word: intead	Frequency: 1
# Word: magnetization	Frequency: 1
# Word: barycentric	Frequency: 1
# Word: mccaslin	Frequency: 1
# Word: perga	Frequency: 1
# Word: parabolas	Frequency: 2
# Word: dandelin	Frequency: 2
# Word: chatelier	Frequency: 2
# Word: waage	Frequency: 1
# Word: molarity	Frequency: 1
# Word: moderna	Frequency: 1
# Word: vaibhav	Frequency: 1
# Word: cattlebeast	Frequency: 1
# Word: derogatively	Frequency: 1
# Word: unpalatable	Frequency: 3
# Word: regurgitating	Frequency: 1
# Word: reswallowed	Frequency: 1
# Word: vgas	Frequency: 1
# Word: omasum	Frequency: 3
# Word: abomasum	Frequency: 2
# Word: poachers	Frequency: 1
# Word: matadors	Frequency: 2
# Word: attractant	Frequency: 1
# Word: mattu	Frequency: 1
# Word: pongal	Frequency: 2
# Word: kamadhenu	Frequency: 1
# Word: rangeland	Frequency: 2
# Word: jallikattu	Frequency: 1
# Word: carting	Frequency: 1
# Word: earmark	Frequency: 1
# Word: milka	Frequency: 2
# Word: mutate	Frequency: 2
# Word: anzovin	Frequency: 1
# Word: searchcattle	Frequency: 1
# Word: baqara	Frequency: 1
# Word: combinadic	Frequency: 1
# Word: shovelware	Frequency: 1
# Word: uninstaller	Frequency: 1
# Word: tapeware	Frequency: 1
# Word: debianwiki	Frequency: 1
# Word: consolatio	Frequency: 4
# Word: charioteers	Frequency: 1
# Word: platonist	Frequency: 2
# Word: divina	Frequency: 1
# Word: boethian	Frequency: 3
# Word: lak	Frequency: 1
# Word: stedfastnesse	Frequency: 1
# Word: manlius	Frequency: 1
# Word: consolatione	Frequency: 2
# Word: yearns	Frequency: 1
# Word: wudang	Frequency: 1
# Word: philosphical	Frequency: 1
# Word: karolus	Frequency: 1
# Word: bertrada	Frequency: 4
# Word: sacramentary	Frequency: 1
# Word: dynasts	Frequency: 1
# Word: ansegisel	Frequency: 3
# Word: begga	Frequency: 2
# Word: landen	Frequency: 2
# Word: arnulfings	Frequency: 1
# Word: charade	Frequency: 1
# Word: reconsideration	Frequency: 1
# Word: petarienses	Frequency: 1
# Word: herstal	Frequency: 1
# Word: typecastings	Frequency: 1
# Word: canitie	Frequency: 1
# Word: chlamys	Frequency: 1
# Word: karoli	Frequency: 2
# Word: caribert	Frequency: 1
# Word: austrasia	Frequency: 4
# Word: waifer	Frequency: 2
# Word: angoul	Frequency: 3
# Word: fronsac	Frequency: 1
# Word: gerberga	Frequency: 2
# Word: paderborn	Frequency: 3
# Word: draconian	Frequency: 2
# Word: eastphalians	Frequency: 2
# Word: gerona	Frequency: 3
# Word: seneschal	Frequency: 1
# Word: flattery	Frequency: 2
# Word: hmerwald	Frequency: 1
# Word: austrasian	Frequency: 1
# Word: thrasuco	Frequency: 1
# Word: raab	Frequency: 1
# Word: khaganate	Frequency: 1
# Word: caliphal	Frequency: 1
# Word: cordoban	Frequency: 1
# Word: ausona	Frequency: 1
# Word: romanum	Frequency: 2
# Word: gubernans	Frequency: 1
# Word: neapolitanus	Frequency: 1
# Word: danevirke	Frequency: 2
# Word: rawson	Frequency: 1
# Word: karolvs	Frequency: 1
# Word: taming	Frequency: 1
# Word: capitularies	Frequency: 1
# Word: salic	Frequency: 1
# Word: christianum	Frequency: 1
# Word: canonisation	Frequency: 1
# Word: desiderata	Frequency: 1
# Word: hildegarde	Frequency: 1
# Word: theodrada	Frequency: 1
# Word: luitgard	Frequency: 1
# Word: concubinages	Frequency: 1
# Word: adaltrude	Frequency: 1
# Word: madelgard	Frequency: 1
# Word: ruodhaid	Frequency: 1
# Word: faremoutiers	Frequency: 1
# Word: carlomagno	Frequency: 1
# Word: santosuosso	Frequency: 1
# Word: apos	Frequency: 3
# Word: tsukuba	Frequency: 2
# Word: intramolecular	Frequency: 5
# Word: gpa	Frequency: 3
# Word: atomically	Frequency: 1
# Word: nanorheostat	Frequency: 1
# Word: monoatomic	Frequency: 1
# Word: ultrahigh	Frequency: 1
# Word: ultrastrong	Frequency: 1
# Word: incandescent	Frequency: 2
# Word: functionalized	Frequency: 1
# Word: aibn	Frequency: 1
# Word: pohang	Frequency: 1
# Word: metallised	Frequency: 1
# Word: jamieson	Frequency: 1
# Word: nantero	Frequency: 1
# Word: challege	Frequency: 1
# Word: smalley	Frequency: 1
# Word: nanotechweb	Frequency: 1
# Word: avouris	Frequency: 1
# Word: quadi	Frequency: 1
# Word: poslaneck	Frequency: 3
# Word: movna	Frequency: 3
# Word: kraje	Frequency: 4
# Word: labe	Frequency: 2
# Word: odra	Frequency: 1
# Word: slackertravel	Frequency: 1
# Word: tschechoslowakei	Frequency: 1
# Word: halers	Frequency: 1
# Word: tatrou	Frequency: 1
# Word: inpatient	Frequency: 2
# Word: extractive	Frequency: 1
# Word: parnas	Frequency: 2
# Word: guilan	Frequency: 1
# Word: mazandaran	Frequency: 3
# Word: astara	Frequency: 2
# Word: xacmas	Frequency: 1
# Word: anzali	Frequency: 1
# Word: rasht	Frequency: 1
# Word: gilan	Frequency: 2
# Word: krasnovodsk	Frequency: 2
# Word: atyrau	Frequency: 1
# Word: behshahr	Frequency: 1
# Word: khvalyn	Frequency: 1
# Word: khvalis	Frequency: 1
# Word: khazaran	Frequency: 1
# Word: caspica	Frequency: 2
# Word: pusa	Frequency: 1
# Word: recasting	Frequency: 3
# Word: sectoral	Frequency: 2
# Word: ceyhan	Frequency: 1
# Word: creatio	Frequency: 1
# Word: radiometric	Frequency: 2
# Word: restate	Frequency: 1
# Word: exegetically	Frequency: 1
# Word: vardy	Frequency: 1
# Word: ljiljana	Frequency: 1
# Word: meritocratic	Frequency: 1
# Word: sanfrancisco	Frequency: 3
# Word: covalence	Frequency: 2
# Word: primack	Frequency: 1
# Word: kanem	Frequency: 19
# Word: baguirmi	Frequency: 15
# Word: kanembu	Frequency: 3
# Word: expandeded	Frequency: 1
# Word: dunama	Frequency: 1
# Word: dabbalemi	Frequency: 1
# Word: ngazargamu	Frequency: 2
# Word: aluma	Frequency: 3
# Word: sabun	Frequency: 3
# Word: ablest	Frequency: 1
# Word: rabih	Frequency: 1
# Word: zubayr	Frequency: 1
# Word: aef	Frequency: 1
# Word: ouadda	Frequency: 10
# Word: frolinat	Frequency: 2
# Word: irrationally	Frequency: 1
# Word: malloum	Frequency: 6
# Word: aouzou	Frequency: 2
# Word: hadjerai	Frequency: 4
# Word: habre	Frequency: 5
# Word: farf	Frequency: 4
# Word: barde	Frequency: 2
# Word: kamougue	Frequency: 2
# Word: doba	Frequency: 6
# Word: destabilize	Frequency: 1
# Word: adre	Frequency: 1
# Word: bioclimatic	Frequency: 1
# Word: sudanian	Frequency: 1
# Word: faya	Frequency: 2
# Word: ubangi	Frequency: 23
# Word: aouk	Frequency: 1
# Word: soudanian	Frequency: 4
# Word: unirrigated	Frequency: 1
# Word: tandjil	Frequency: 2
# Word: kordofanian	Frequency: 2
# Word: chadians	Frequency: 3
# Word: hajerai	Frequency: 1
# Word: kanembou	Frequency: 2
# Word: boulala	Frequency: 1
# Word: maba	Frequency: 1
# Word: ngambaye	Frequency: 1
# Word: goulaye	Frequency: 1
# Word: moundang	Frequency: 1
# Word: massa	Frequency: 2
# Word: tandjile	Frequency: 1
# Word: ngarlegy	Frequency: 1
# Word: ngarlejy	Frequency: 1
# Word: wadal	Frequency: 1
# Word: delwa	Frequency: 1
# Word: bdeac	Frequency: 3
# Word: crackdowns	Frequency: 2
# Word: udeac	Frequency: 4
# Word: snark	Frequency: 4
# Word: jabberwocky	Frequency: 1
# Word: parsonage	Frequency: 2
# Word: maths	Frequency: 2
# Word: stammer	Frequency: 5
# Word: exhaustively	Frequency: 1
# Word: stammered	Frequency: 2
# Word: caracatured	Frequency: 1
# Word: nuneham	Frequency: 1
# Word: joycean	Frequency: 1
# Word: karoline	Frequency: 5
# Word: untainted	Frequency: 1
# Word: lebailly	Frequency: 1
# Word: alibis	Frequency: 1
# Word: nyctography	Frequency: 1
# Word: lcsna	Frequency: 1
# Word: rugbeians	Frequency: 1
# Word: colloidial	Frequency: 1
# Word: foams	Frequency: 2
# Word: confocal	Frequency: 1
# Word: explainable	Frequency: 2
# Word: disputable	Frequency: 2
# Word: banditos	Frequency: 1
# Word: unadded	Frequency: 5
# Word: pasted	Frequency: 3
# Word: offal	Frequency: 1
# Word: mucilaginous	Frequency: 1
# Word: saccharides	Frequency: 1
# Word: waterbased	Frequency: 1
# Word: emulsification	Frequency: 1
# Word: caramelisation	Frequency: 1
# Word: braising	Frequency: 2
# Word: microwaving	Frequency: 1
# Word: barbecuing	Frequency: 3
# Word: tahini	Frequency: 1
# Word: equivalencies	Frequency: 1
# Word: culinarychef	Frequency: 1
# Word: culinaire	Frequency: 1
# Word: undealt	Frequency: 1
# Word: redeal	Frequency: 1
# Word: skatverband	Frequency: 1
# Word: sueca	Frequency: 1
# Word: durak	Frequency: 1
# Word: haihowak	Frequency: 1
# Word: craits	Frequency: 1
# Word: narabe	Frequency: 1
# Word: slapjack	Frequency: 1
# Word: duelmasters	Frequency: 1
# Word: scopa	Frequency: 1
# Word: mythadventures	Frequency: 1
# Word: sabacc	Frequency: 1
# Word: backstitches	Frequency: 1
# Word: evenweave	Frequency: 2
# Word: blackwork	Frequency: 2
# Word: dishwear	Frequency: 1
# Word: hardanger	Frequency: 1
# Word: laydenwithstitches	Frequency: 1
# Word: realistitch	Frequency: 1
# Word: wagered	Frequency: 2
# Word: handhelds	Frequency: 3
# Word: turbografx	Frequency: 2
# Word: megadrive	Frequency: 1
# Word: virtua	Frequency: 1
# Word: starfox	Frequency: 1
# Word: gamespy	Frequency: 1
# Word: materializing	Frequency: 1
# Word: mesmerization	Frequency: 1
# Word: fossilizable	Frequency: 1
# Word: caerfai	Frequency: 1
# Word: albertian	Frequency: 1
# Word: paibian	Frequency: 1
# Word: archeocyathids	Frequency: 1
# Word: palaeogeography	Frequency: 1
# Word: paleomaps	Frequency: 1
# Word: ediacarian	Frequency: 1
# Word: paleomap	Frequency: 1
# Word: modality	Frequency: 1
# Word: sellars	Frequency: 2
# Word: physicalism	Frequency: 2
# Word: rheinhardt	Frequency: 1
# Word: amie	Frequency: 2
# Word: thomassen	Frequency: 1
# Word: attenuating	Frequency: 1
# Word: entrainers	Frequency: 1
# Word: astm	Frequency: 1
# Word: litracon	Frequency: 1
# Word: ecosmart	Frequency: 1
# Word: lubricatory	Frequency: 1
# Word: reservatus	Frequency: 1
# Word: sonya	Frequency: 1
# Word: trafficked	Frequency: 2
# Word: quondam	Frequency: 1
# Word: vulcanized	Frequency: 1
# Word: breakages	Frequency: 1
# Word: trichomonas	Frequency: 2
# Word: kanyoro	Frequency: 2
# Word: drape	Frequency: 1
# Word: anglaise	Frequency: 2
# Word: procreative	Frequency: 3
# Word: orgasms	Frequency: 1
# Word: trigramme	Frequency: 1
# Word: territoriales	Frequency: 1
# Word: statistiques	Frequency: 1
# Word: statoids	Frequency: 1
# Word: wab	Frequency: 1
# Word: cladogram	Frequency: 8
# Word: klados	Frequency: 1
# Word: vernation	Frequency: 1
# Word: apomorphy	Frequency: 3
# Word: characterising	Frequency: 2
# Word: homoplasies	Frequency: 1
# Word: homoplasy	Frequency: 3
# Word: sparsity	Frequency: 1
# Word: pachydermata	Frequency: 1
# Word: systematists	Frequency: 1
# Word: hominidae	Frequency: 1
# Word: intercalation	Frequency: 1
# Word: birashk	Frequency: 1
# Word: kalenderrechnung	Frequency: 1
# Word: imager	Frequency: 1
# Word: reionization	Frequency: 1
# Word: axion	Frequency: 1
# Word: unmathematical	Frequency: 1
# Word: inflaton	Frequency: 5
# Word: brandenberger	Frequency: 1
# Word: sanitization	Frequency: 6
# Word: bespatter	Frequency: 1
# Word: glavlit	Frequency: 5
# Word: untennable	Frequency: 1
# Word: autocensorship	Frequency: 1
# Word: censorware	Frequency: 1
# Word: ncac	Frequency: 1
# Word: darel	Frequency: 1
# Word: cleans	Frequency: 1
# Word: steradian	Frequency: 1
# Word: candlepower	Frequency: 1
# Word: courcheval	Frequency: 1
# Word: chowaha	Frequency: 4
# Word: quasicrystals	Frequency: 1
# Word: plasmon	Frequency: 1
# Word: nanoelectromechanical	Frequency: 1
# Word: trobriand	Frequency: 2
# Word: ethnographers	Frequency: 3
# Word: superficiality	Frequency: 1
# Word: comaroff	Frequency: 2
# Word: quintal	Frequency: 1
# Word: saskia	Frequency: 1
# Word: sassen	Frequency: 2
# Word: importances	Frequency: 1
# Word: kanter	Frequency: 2
# Word: informationen	Frequency: 1
# Word: garlics	Frequency: 1
# Word: flowercapsules	Frequency: 1
# Word: traineeship	Frequency: 1
# Word: iannucci	Frequency: 2
# Word: marber	Frequency: 2
# Word: paedophile	Frequency: 2
# Word: smokehammer	Frequency: 2
# Word: bushwhacked	Frequency: 1
# Word: trashbat	Frequency: 1
# Word: notionally	Frequency: 1
# Word: platte	Frequency: 5
# Word: snowpack	Frequency: 1
# Word: juans	Frequency: 1
# Word: hispanos	Frequency: 1
# Word: castlewood	Frequency: 1
# Word: vona	Frequency: 1
# Word: arapaho	Frequency: 3
# Word: curecanti	Frequency: 1
# Word: pawnee	Frequency: 1
# Word: garita	Frequency: 1
# Word: rawah	Frequency: 1
# Word: quickfacts	Frequency: 1
# Word: wiatrowski	Frequency: 1
# Word: pennsylvanian	Frequency: 1
# Word: noginskian	Frequency: 1
# Word: kasimovian	Frequency: 1
# Word: chamovnicheskian	Frequency: 1
# Word: krevyakinskian	Frequency: 1
# Word: myachkovskian	Frequency: 1
# Word: bolsovian	Frequency: 2
# Word: podolskian	Frequency: 1
# Word: kashirskian	Frequency: 1
# Word: vereiskian	Frequency: 1
# Word: bashkirian	Frequency: 1
# Word: melekesskian	Frequency: 1
# Word: duckmantian	Frequency: 1
# Word: yeadonian	Frequency: 1
# Word: marsdenian	Frequency: 1
# Word: kinderscoutian	Frequency: 1
# Word: alportian	Frequency: 1
# Word: pendleian	Frequency: 1
# Word: visean	Frequency: 1
# Word: meramecian	Frequency: 2
# Word: arundian	Frequency: 1
# Word: tournaisian	Frequency: 1
# Word: hastarian	Frequency: 1
# Word: paleogeography	Frequency: 2
# Word: amniote	Frequency: 2
# Word: desiccation	Frequency: 1
# Word: clasified	Frequency: 1
# Word: hyman	Frequency: 2
# Word: lawschool	Frequency: 1
# Word: anjouan	Frequency: 19
# Word: azali	Frequency: 19
# Word: assoumani	Frequency: 6
# Word: tadjidine	Frequency: 2
# Word: massounde	Frequency: 2
# Word: bainrifi	Frequency: 2
# Word: madi	Frequency: 2
# Word: comorians	Frequency: 4
# Word: gemma	Frequency: 4
# Word: watwan	Frequency: 1
# Word: categorizes	Frequency: 1
# Word: enlai	Frequency: 1
# Word: assertiveness	Frequency: 1
# Word: shaanxi	Frequency: 3
# Word: tianchi	Frequency: 1
# Word: baitou	Frequency: 1
# Word: saihanba	Frequency: 1
# Word: xijiang	Frequency: 1
# Word: aksai	Frequency: 1
# Word: arunachal	Frequency: 1
# Word: diaoyu	Frequency: 1
# Word: balkhash	Frequency: 1
# Word: eas	Frequency: 1
# Word: zhuhai	Frequency: 1
# Word: xiamen	Frequency: 2
# Word: lijiang	Frequency: 1
# Word: confucians	Frequency: 5
# Word: militarize	Frequency: 1
# Word: eastday	Frequency: 1
# Word: havenworks	Frequency: 2
# Word: earlywarning	Frequency: 1
# Word: dalian	Frequency: 1
# Word: taikonauts	Frequency: 1
# Word: sergas	Frequency: 1
# Word: esplandi	Frequency: 1
# Word: salinan	Frequency: 1
# Word: cabrillo	Frequency: 1
# Word: decimation	Frequency: 2
# Word: didacus	Frequency: 1
# Word: schwarzeneggar	Frequency: 1
# Word: lyonothamnus	Frequency: 1
# Word: ceanothus	Frequency: 1
# Word: sequoias	Frequency: 1
# Word: sanjosedowntownimg	Frequency: 1
# Word: atherton	Frequency: 1
# Word: portola	Frequency: 1
# Word: tassajara	Frequency: 1
# Word: plumas	Frequency: 3
# Word: mendota	Frequency: 1
# Word: madera	Frequency: 1
# Word: biola	Frequency: 1
# Word: calarts	Frequency: 1
# Word: sabercats	Frequency: 1
# Word: chivas	Frequency: 1
# Word: caltrans	Frequency: 2
# Word: caltrain	Frequency: 1
# Word: altamont	Frequency: 1
# Word: kinbasket	Frequency: 1
# Word: ilwaco	Frequency: 1
# Word: southeasterly	Frequency: 2
# Word: hanford	Frequency: 2
# Word: willamette	Frequency: 2
# Word: kootenai	Frequency: 1
# Word: klickitat	Frequency: 1
# Word: unmapped	Frequency: 1
# Word: hoarding	Frequency: 4
# Word: dumpage	Frequency: 1
# Word: cathlamet	Frequency: 1
# Word: commelinaceae	Frequency: 3
# Word: rapataceae	Frequency: 1
# Word: xyridaceae	Frequency: 2
# Word: mayacaceae	Frequency: 1
# Word: commelinidae	Frequency: 1
# Word: philydraceae	Frequency: 1
# Word: cyperales	Frequency: 3
# Word: cyperaceae	Frequency: 2
# Word: juncales	Frequency: 1
# Word: juncaceae	Frequency: 1
# Word: violales	Frequency: 2
# Word: dilleniidae	Frequency: 2
# Word: tetramelaceae	Frequency: 2
# Word: anisophylleaceae	Frequency: 1
# Word: contredanse	Frequency: 2
# Word: contradancers	Frequency: 1
# Word: enrapture	Frequency: 1
# Word: promenades	Frequency: 1
# Word: actives	Frequency: 2
# Word: hoarded	Frequency: 1
# Word: overdates	Frequency: 1
# Word: guaranty	Frequency: 2
# Word: squails	Frequency: 1
# Word: shuffleboard	Frequency: 1
# Word: nowdays	Frequency: 1
# Word: capitalis	Frequency: 1
# Word: faihu	Frequency: 1
# Word: rupya	Frequency: 1
# Word: kapitalist	Frequency: 2
# Word: commodification	Frequency: 3
# Word: specialisation	Frequency: 3
# Word: constraining	Frequency: 2
# Word: underclasses	Frequency: 1
# Word: attenuate	Frequency: 1
# Word: complacent	Frequency: 1
# Word: reserachers	Frequency: 1
# Word: flattening	Frequency: 1
# Word: neoliberals	Frequency: 1
# Word: maddison	Frequency: 1
# Word: localism	Frequency: 1
# Word: niaf	Frequency: 1
# Word: walberg	Frequency: 1
# Word: globalist	Frequency: 2
# Word: stagnating	Frequency: 2
# Word: reallocation	Frequency: 1
# Word: cardiologists	Frequency: 1
# Word: myocardium	Frequency: 8
# Word: sinoatrial	Frequency: 5
# Word: subaortic	Frequency: 1
# Word: pulmonale	Frequency: 1
# Word: myxoma	Frequency: 1
# Word: tamponade	Frequency: 1
# Word: prolapse	Frequency: 1
# Word: supraventricular	Frequency: 4
# Word: tachy	Frequency: 1
# Word: avnrt	Frequency: 1
# Word: avrt	Frequency: 1
# Word: torsades	Frequency: 1
# Word: trifascicular	Frequency: 1
# Word: brugada	Frequency: 2
# Word: arteriosus	Frequency: 1
# Word: fallot	Frequency: 1
# Word: atherectomy	Frequency: 1
# Word: electrocardiogram	Frequency: 2
# Word: sphygmomanometer	Frequency: 1
# Word: candesartan	Frequency: 1
# Word: losartan	Frequency: 1
# Word: telmisartan	Frequency: 1
# Word: interventional	Frequency: 2
# Word: asiahq	Frequency: 1
# Word: industryentertainment	Frequency: 1
# Word: okamotoshinji	Frequency: 1
# Word: evilbreath	Frequency: 1
# Word: funan	Frequency: 1
# Word: chenla	Frequency: 1
# Word: jayavarman	Frequency: 3
# Word: interdynastic	Frequency: 1
# Word: sihanoukville	Frequency: 7
# Word: sary	Frequency: 3
# Word: counterrevolutionaires	Frequency: 1
# Word: kampuchean	Frequency: 6
# Word: stearns	Frequency: 1
# Word: monsoonal	Frequency: 3
# Word: takev	Frequency: 1
# Word: korat	Frequency: 1
# Word: airflows	Frequency: 1
# Word: kracheh	Frequency: 2
# Word: chattomukh	Frequency: 1
# Word: sab	Frequency: 6
# Word: basak	Frequency: 3
# Word: aoral	Frequency: 1
# Word: chairing	Frequency: 1
# Word: ranariddh	Frequency: 1
# Word: rainsy	Frequency: 2
# Word: preahm	Frequency: 7
# Word: haksat	Frequency: 3
# Word: seihamuni	Frequency: 1
# Word: haviraksat	Frequency: 4
# Word: vira	Frequency: 1
# Word: cambodge	Frequency: 1
# Word: pracheachon	Frequency: 1
# Word: khsay	Frequency: 1
# Word: ambel	Frequency: 1
# Word: renascent	Frequency: 1
# Word: batdambang	Frequency: 1
# Word: akaschor	Frequency: 1
# Word: rcaf	Frequency: 1
# Word: transhipment	Frequency: 1
# Word: devata	Frequency: 1
# Word: banteay	Frequency: 6
# Word: gopuras	Frequency: 2
# Word: hallways	Frequency: 1
# Word: dharmasala	Frequency: 1
# Word: javarman	Frequency: 1
# Word: kalas	Frequency: 1
# Word: naga	Frequency: 3
# Word: barays	Frequency: 2
# Word: jayatataka	Frequency: 1
# Word: algiedi	Frequency: 3
# Word: stabled	Frequency: 1
# Word: galle	Frequency: 1
# Word: capricorni	Frequency: 1
# Word: harks	Frequency: 1
# Word: nashira	Frequency: 1
# Word: irah	Frequency: 1
# Word: acidify	Frequency: 1
# Word: cheddaring	Frequency: 2
# Word: cheesemakers	Frequency: 1
# Word: raclette	Frequency: 1
# Word: ricotta	Frequency: 2
# Word: cheesemaking	Frequency: 14
# Word: strainers	Frequency: 1
# Word: cheddar	Frequency: 27
# Word: halal	Frequency: 3
# Word: spoilage	Frequency: 1
# Word: spreadable	Frequency: 1
# Word: gorgonzola	Frequency: 2
# Word: inoculating	Frequency: 1
# Word: assertive	Frequency: 1
# Word: edam	Frequency: 2
# Word: histamine	Frequency: 1
# Word: lactococci	Frequency: 1
# Word: lactobacilli	Frequency: 2
# Word: shermani	Frequency: 1
# Word: affinage	Frequency: 1
# Word: milkfat	Frequency: 2
# Word: vacherin	Frequency: 1
# Word: brevibacterium	Frequency: 1
# Word: cacio	Frequency: 1
# Word: caws	Frequency: 1
# Word: formaggio	Frequency: 1
# Word: expropriates	Frequency: 1
# Word: baka	Frequency: 8
# Word: ahmadou	Frequency: 2
# Word: ahidjo	Frequency: 6
# Word: rainfalls	Frequency: 1
# Word: bamenda	Frequency: 2
# Word: mambilla	Frequency: 1
# Word: southwestward	Frequency: 1
# Word: kadei	Frequency: 1
# Word: garoua	Frequency: 2
# Word: bamun	Frequency: 3
# Word: foumban	Frequency: 1
# Word: bassa	Frequency: 3
# Word: duala	Frequency: 3
# Word: dateenglish	Frequency: 1
# Word: bakweri	Frequency: 1
# Word: suppressant	Frequency: 1
# Word: ambam	Frequency: 1
# Word: bikya	Frequency: 1
# Word: bouba	Frequency: 2
# Word: cavaye	Frequency: 1
# Word: mendouga	Frequency: 1
# Word: ndam	Frequency: 2
# Word: garga	Frequency: 1
# Word: dakole	Frequency: 1
# Word: unitar	Frequency: 1
# Word: esaf	Frequency: 1
# Word: fora	Frequency: 4
# Word: bakasi	Frequency: 1
# Word: verdeans	Frequency: 9
# Word: capeverde	Frequency: 1
# Word: barlaventos	Frequency: 1
# Word: razo	Frequency: 1
# Word: velha	Frequency: 1
# Word: tarrafal	Frequency: 4
# Word: verdean	Frequency: 10
# Word: verdians	Frequency: 1
# Word: fado	Frequency: 1
# Word: funana	Frequency: 1
# Word: vadinho	Frequency: 1
# Word: claridade	Frequency: 1
# Word: vasconcelos	Frequency: 1
# Word: alves	Frequency: 3
# Word: aguinaldo	Frequency: 1
# Word: poesia	Frequency: 2
# Word: sopinha	Frequency: 1
# Word: cavaquim	Frequency: 1
# Word: travadinha	Frequency: 1
# Word: bau	Frequency: 1
# Word: celina	Frequency: 1
# Word: cordas	Frequency: 1
# Word: fantcha	Frequency: 1
# Word: morais	Frequency: 1
# Word: lura	Frequency: 1
# Word: tubar	Frequency: 1
# Word: semana	Frequency: 4
# Word: cidadao	Frequency: 2
# Word: balla	Frequency: 2
# Word: archipelagic	Frequency: 1
# Word: pozzuolana	Frequency: 1
# Word: volcanically	Frequency: 1
# Word: armindo	Frequency: 1
# Word: mascarenhas	Frequency: 5
# Word: wahnon	Frequency: 1
# Word: rua	Frequency: 1
# Word: macedo	Frequency: 1
# Word: usembassy	Frequency: 1
# Word: interisland	Frequency: 1
# Word: tacv	Frequency: 1
# Word: maestra	Frequency: 6
# Word: leucocephala	Frequency: 2
# Word: tortugas	Frequency: 2
# Word: caymanas	Frequency: 2
# Word: adjusters	Frequency: 1
# Word: garmin	Frequency: 1
# Word: centrafricaine	Frequency: 2
# Word: sahelo	Frequency: 1
# Word: patass	Frequency: 23
# Word: nzakara	Frequency: 1
# Word: zande	Frequency: 2
# Word: savorgnan	Frequency: 1
# Word: brazza	Frequency: 3
# Word: procolonial	Frequency: 1
# Word: concessionary	Frequency: 2
# Word: anticolonial	Frequency: 1
# Word: gaullist	Frequency: 1
# Word: goumba	Frequency: 7
# Word: bokassa	Frequency: 9
# Word: rassemblement	Frequency: 3
# Word: mocratique	Frequency: 2
# Word: centrafricain	Frequency: 3
# Word: gbaya	Frequency: 1
# Word: kaba	Frequency: 1
# Word: interafricaine	Frequency: 1
# Word: bedaya	Frequency: 1
# Word: ayous	Frequency: 1
# Word: plantains	Frequency: 3
# Word: bushmeat	Frequency: 2
# Word: bamingui	Frequency: 2
# Word: democratization	Frequency: 3
# Word: ngaoui	Frequency: 1
# Word: berberati	Frequency: 3
# Word: ombella	Frequency: 1
# Word: boali	Frequency: 1
# Word: communaute	Frequency: 2
# Word: financiere	Frequency: 2
# Word: cfaf	Frequency: 6
# Word: panaftel	Frequency: 1
# Word: gamboula	Frequency: 1
# Word: nationlink	Frequency: 1
# Word: salo	Frequency: 2
# Word: centrafricaines	Frequency: 1
# Word: caemc	Frequency: 1
# Word: taire	Frequency: 5
# Word: copax	Frequency: 1
# Word: beac	Frequency: 3
# Word: lamis	Frequency: 1
# Word: fira	Frequency: 1
# Word: evangeliques	Frequency: 1
# Word: pizarro	Frequency: 3
# Word: mapuches	Frequency: 3
# Word: altamirano	Frequency: 2
# Word: palacio	Frequency: 1
# Word: concertaci	Frequency: 4
# Word: tagle	Frequency: 4
# Word: escobar	Frequency: 7
# Word: bachelet	Frequency: 9
# Word: gobernador	Frequency: 1
# Word: comunas	Frequency: 1
# Word: consejales	Frequency: 1
# Word: ftas	Frequency: 2
# Word: talcahuano	Frequency: 3
# Word: reacquire	Frequency: 1
# Word: rapanui	Frequency: 1
# Word: tonada	Frequency: 1
# Word: chilena	Frequency: 1
# Word: rosea	Frequency: 1
# Word: fuerza	Frequency: 5
# Word: relaciones	Frequency: 1
# Word: choapa	Frequency: 1
# Word: encomiendas	Frequency: 2
# Word: arauco	Frequency: 1
# Word: tucapel	Frequency: 2
# Word: lautaro	Frequency: 7
# Word: dundonald	Frequency: 2
# Word: balmaceda	Frequency: 6
# Word: radomiro	Frequency: 2
# Word: stange	Frequency: 2
# Word: technocrats	Frequency: 1
# Word: beggars	Frequency: 1
# Word: concertacion	Frequency: 4
# Word: socialista	Frequency: 1
# Word: democracia	Frequency: 1
# Word: copiap	Frequency: 2
# Word: michimalonco	Frequency: 1
# Word: juntista	Frequency: 1
# Word: exaltados	Frequency: 1
# Word: camilo	Frequency: 1
# Word: nza	Frequency: 1
# Word: archipi	Frequency: 1
# Word: maroto	Frequency: 1
# Word: encalada	Frequency: 2
# Word: portales	Frequency: 3
# Word: portalian	Frequency: 1
# Word: theperuvian	Frequency: 1
# Word: purapel	Frequency: 1
# Word: decenal	Frequency: 1
# Word: araucan	Frequency: 2
# Word: preocupation	Frequency: 1
# Word: independencia	Frequency: 1
# Word: angamos	Frequency: 1
# Word: policarpo	Frequency: 1
# Word: parliamentarism	Frequency: 1
# Word: escuela	Frequency: 1
# Word: complementario	Frequency: 1
# Word: cerda	Frequency: 1
# Word: neoliberalism	Frequency: 4
# Word: vocales	Frequency: 3
# Word: contralor	Frequency: 2
# Word: vitalicios	Frequency: 1
# Word: confederations	Frequency: 1
# Word: opanal	Frequency: 3
# Word: encaje	Frequency: 1
# Word: cacm	Frequency: 2
# Word: efta	Frequency: 1
# Word: longuimay	Frequency: 1
# Word: codina	Frequency: 1
# Word: relatins	Frequency: 1
# Word: agrreed	Frequency: 1
# Word: velasco	Frequency: 3
# Word: pintado	Frequency: 2
# Word: arteaga	Frequency: 2
# Word: cesado	Frequency: 1
# Word: sangrienta	Frequency: 1
# Word: afrenta	Frequency: 1
# Word: esclavo	Frequency: 1
# Word: triunfante	Frequency: 1
# Word: asilo	Frequency: 1
# Word: conquistaste	Frequency: 1
# Word: valiente	Frequency: 1
# Word: tranquilos	Frequency: 1
# Word: artes	Frequency: 1
# Word: spota	Frequency: 1
# Word: audaz	Frequency: 1
# Word: lancemos	Frequency: 1
# Word: marchando	Frequency: 1
# Word: sonando	Frequency: 1
# Word: tirano	Frequency: 1
# Word: temblar	Frequency: 1
# Word: extranjero	Frequency: 1
# Word: altivo	Frequency: 1
# Word: tiembla	Frequency: 1
# Word: mano	Frequency: 1
# Word: puras	Frequency: 1
# Word: brisas	Frequency: 1
# Word: bordado	Frequency: 1
# Word: copia	Frequency: 1
# Word: majestuosa	Frequency: 1
# Word: tranquilo	Frequency: 1
# Word: esas	Frequency: 2
# Word: tapizan	Frequency: 1
# Word: invasores	Frequency: 1
# Word: estandarte	Frequency: 1
# Word: kiritimati	Frequency: 1
# Word: palapa	Frequency: 1
# Word: boatload	Frequency: 1
# Word: dotars	Frequency: 2
# Word: spaceport	Frequency: 1
# Word: streamer	Frequency: 1
# Word: unloading	Frequency: 1
# Word: mancanilla	Frequency: 1
# Word: ipomoea	Frequency: 1
# Word: curassavicum	Frequency: 1
# Word: rhombifolia	Frequency: 1
# Word: aestuans	Frequency: 1
# Word: juncea	Frequency: 1
# Word: blas	Frequency: 6
# Word: reasserted	Frequency: 1
# Word: victoriano	Frequency: 1
# Word: cousteau	Frequency: 1
# Word: lingiari	Frequency: 1
# Word: lighterage	Frequency: 1
# Word: allots	Frequency: 1
# Word: mythmakers	Frequency: 1
# Word: goffman	Frequency: 1
# Word: skeptically	Frequency: 2
# Word: feyerabend	Frequency: 1
# Word: posttraumatic	Frequency: 1
# Word: barkun	Frequency: 1
# Word: rauni	Frequency: 1
# Word: luukanen	Frequency: 1
# Word: grann	Frequency: 1
# Word: nesara	Frequency: 1
# Word: pnac	Frequency: 1
# Word: mattei	Frequency: 1
# Word: duggan	Frequency: 1
# Word: alternet	Frequency: 1
# Word: conspiration	Frequency: 1
# Word: sociopathy	Frequency: 1
# Word: magdelaine	Frequency: 2
# Word: wansfell	Frequency: 1
# Word: oceandots	Frequency: 1
# Word: exclamative	Frequency: 1
# Word: hermosa	Frequency: 1
# ...
# Word: pedreiras	Frequency: 1
# Word: valongo	Frequency: 1
# Word: hejszowina	Frequency: 1
# Word: krakowsko	Frequency: 1
# Word: stochowska	Frequency: 1
# Word: tatra	Frequency: 1
# Word: hiitola	Frequency: 1
# Word: jastrebinoe	Frequency: 1
# Word: caucas	Frequency: 1
# Word: pjatigorsk	Frequency: 1
# Word: daurada	Frequency: 1
# Word: bugaboos	Frequency: 1
# Word: charlevoix	Frequency: 1
# Word: calaveras	Frequency: 2
# Word: tahquitz	Frequency: 1
# Word: adirondacks	Frequency: 1
# Word: shawangunks	Frequency: 1
# Word: krahlick	Frequency: 1
# Word: canyonlands	Frequency: 1
# Word: wasatch	Frequency: 1
# Word: mazama	Frequency: 1
# Word: vedauwoo	Frequency: 1
# Word: gruta	Frequency: 1
# Word: diamantina	Frequency: 1
# Word: lagoas	Frequency: 1
# Word: itajub	Frequency: 1
# Word: pedra	Frequency: 1
# Word: betamax	Frequency: 1
# Word: disambiguously	Frequency: 1
# Word: polyacetals	Frequency: 1
# Word: agoura	Frequency: 1
# Word: cannisters	Frequency: 1
# Word: kaohsiung	Frequency: 1
# Word: bankstown	Frequency: 1
# Word: broadmoor	Frequency: 1
# Word: cheyennemountain	Frequency: 1
# Word: noca	Frequency: 1
# Word: comptia	Frequency: 1
# Word: profesional	Frequency: 1
# Word: sandec	Frequency: 1
# Word: hofrat	Frequency: 1
# Word: herrenhaus	Frequency: 1
# Word: brubaker	Frequency: 1
# Word: lagaffe	Frequency: 1
# Word: glashan	Frequency: 1
# Word: palnik	Frequency: 3
# Word: partch	Frequency: 1
# Word: penuelas	Frequency: 1
# Word: lavado	Frequency: 1
# Word: tayler	Frequency: 1
# Word: astroboy	Frequency: 1
# Word: deja	Frequency: 1
# Word: kahl	Frequency: 1
# Word: kricfalusi	Frequency: 1
# Word: natwick	Frequency: 1
# Word: reitherman	Frequency: 1
# Word: sharpsteen	Frequency: 1
# Word: tytla	Frequency: 1
# Word: palooka	Frequency: 1
# Word: lasswell	Frequency: 1
# Word: nease	Frequency: 2
# Word: peattie	Frequency: 1
# Word: caroll	Frequency: 1
# Word: tads	Frequency: 1
# Word: chappatte	Frequency: 2
# Word: chast	Frequency: 1
# Word: grea	Frequency: 1
# Word: horacek	Frequency: 1
# Word: gahan	Frequency: 1
# Word: naji	Frequency: 1
# Word: koraksic	Frequency: 1
# Word: corax	Frequency: 1
# Word: molnar	Frequency: 1
# Word: aislin	Frequency: 1
# Word: metroland	Frequency: 1
# Word: kurtzman	Frequency: 1
# Word: pran	Frequency: 1
# Word: quackup	Frequency: 1
# Word: pantabangan	Frequency: 1
# Word: mangaka	Frequency: 1
# Word: barbarity	Frequency: 1
# Word: kardashev	Frequency: 3
# Word: immoderate	Frequency: 1
# Word: ppna	Frequency: 1
# Word: grahamhancock	Frequency: 1
# Word: harappan	Frequency: 1
# Word: lothal	Frequency: 1
# Word: craftsmenship	Frequency: 1
# Word: multiversal	Frequency: 1
# Word: kumakura	Frequency: 1
# Word: arther	Frequency: 1
# Word: micromanagement	Frequency: 1
# Word: expansionistic	Frequency: 1
# Word: hotseat	Frequency: 1
# Word: moddable	Frequency: 1
# Word: hartland	Frequency: 1
# Word: stardock	Frequency: 1
# Word: maelstrom	Frequency: 1
# Word: trivialization	Frequency: 1
# Word: featurism	Frequency: 1
# Word: kapell	Frequency: 1
# Word: daglow	Frequency: 1
# Word: civfanatics	Frequency: 1
# Word: zuleima	Frequency: 1
# Word: damoiselle	Frequency: 2
# Word: fantaisie	Frequency: 2
# Word: wagnerian	Frequency: 1
# Word: faune	Frequency: 1
# Word: lisande	Frequency: 3
# Word: vagues	Frequency: 1
# Word: bergamasque	Frequency: 2
# Word: verlainian	Frequency: 2
# Word: khamma	Frequency: 2
# Word: arrau	Frequency: 1
# Word: rarefaction	Frequency: 1
# Word: gazer	Frequency: 1
# Word: mouglalis	Frequency: 1
# Word: pigraphes	Frequency: 1
# Word: gaillard	Frequency: 1
# Word: pantonality	Frequency: 1
# Word: marginalising	Frequency: 1
# Word: cosmopolitanism	Frequency: 1
# Word: trivializes	Frequency: 2
# Word: isomerisation	Frequency: 1
# Word: agno	Frequency: 1
# Word: carbenes	Frequency: 1
# Word: enthalpies	Frequency: 2
# Word: distributary	Frequency: 1
# Word: yturriaga	Frequency: 1
# Word: bonpland	Frequency: 1
# Word: stellation	Frequency: 1
# Word: orthobicupola	Frequency: 1
# Word: cubetruncated	Frequency: 1
# Word: cubecuboctahedron	Frequency: 1
# Word: quasiregular	Frequency: 1
# Word: hexahedron	Frequency: 2
# Word: octangula	Frequency: 2
# Word: zonohedra	Frequency: 1
# Word: luas	Frequency: 1
# Word: metrovalpara	Frequency: 1
# Word: wandlebury	Frequency: 2
# Word: madingley	Frequency: 1
# Word: godmanchester	Frequency: 1
# Word: hanglands	Frequency: 1
# Word: watermill	Frequency: 1
# Word: hereward	Frequency: 1
# Word: bramleyline	Frequency: 1
# Word: publilian	Frequency: 1
# Word: periochae	Frequency: 3
# Word: centuriate	Frequency: 4
# Word: curiate	Frequency: 1
# Word: auspicia	Frequency: 1
# Word: coriolanus	Frequency: 1
# Word: magistratus	Frequency: 1
# Word: flaminius	Frequency: 1
# Word: lustra	Frequency: 2
# Word: caecil	Frequency: 1
# Word: plancus	Frequency: 1
# Word: symmach	Frequency: 2
# Word: vias	Frequency: 1
# Word: pacilus	Frequency: 1
# Word: macerinus	Frequency: 1
# Word: censoriae	Frequency: 3
# Word: statorius	Frequency: 1
# Word: heracl	Frequency: 1
# Word: digesta	Frequency: 2
# Word: quiritarian	Frequency: 3
# Word: flacc	Frequency: 1
# Word: varr	Frequency: 2
# Word: savigny	Frequency: 1
# Word: cassiod	Frequency: 1
# Word: significations	Frequency: 1
# Word: animadversio	Frequency: 2
# Word: partiality	Frequency: 1
# Word: ignominia	Frequency: 3
# Word: sumtuariae	Frequency: 1
# Word: praeteriti	Frequency: 2
# Word: aerarios	Frequency: 1
# Word: aerarius	Frequency: 2
# Word: sacras	Frequency: 1
# Word: ultrotributa	Frequency: 2
# Word: basilicae	Frequency: 1
# Word: acceptum	Frequency: 1
# Word: hyperplane	Frequency: 3
# Word: stiintsa	Frequency: 1
# Word: qahirah	Frequency: 1
# Word: mameluk	Frequency: 1
# Word: westernization	Frequency: 1
# Word: cairofromtower	Frequency: 1
# Word: ainy	Frequency: 1
# Word: naguib	Frequency: 1
# Word: azhar	Frequency: 1
# Word: maadi	Frequency: 1
# Word: alahram	Frequency: 1
# Word: acu	Frequency: 1
# Word: anosov	Frequency: 2
# Word: attractor	Frequency: 8
# Word: ueda	Frequency: 5
# Word: hayashi	Frequency: 1
# Word: feigenbaum	Frequency: 1
# Word: semitechnical	Frequency: 1
# Word: strogatz	Frequency: 1
# Word: chaosbook	Frequency: 1
# Word: calspan	Frequency: 1
# Word: dashboards	Frequency: 1
# Word: planum	Frequency: 1
# Word: interoperatibility	Frequency: 1
# Word: arecibo	Frequency: 1
# Word: shackelton	Frequency: 1
# Word: arnot	Frequency: 1
# Word: balch	Frequency: 1
# Word: upperclassmen	Frequency: 2
# Word: akwe	Frequency: 1
# Word: ecac	Frequency: 2
# Word: cornelliana	Frequency: 3
# Word: cornellian	Frequency: 3
# Word: cornellians	Frequency: 2
# Word: caboose	Frequency: 1
# Word: vampiro	Frequency: 1
# Word: tolapa	Frequency: 1
# Word: unan	Frequency: 1
# Word: chupanibre	Frequency: 1
# Word: frontenac	Frequency: 2
# Word: levanna	Frequency: 1
# Word: canoga	Frequency: 1
# Word: marinas	Frequency: 1
# Word: palisades	Frequency: 1
# Word: manhattanville	Frequency: 1
# Word: barzun	Frequency: 2
# Word: lazarsfeld	Frequency: 1
# Word: polykarp	Frequency: 1
# Word: meadmore	Frequency: 1
# Word: philolexian	Frequency: 2
# Word: schapiro	Frequency: 1
# Word: culpa	Frequency: 4
# Word: grapples	Frequency: 1
# Word: luckman	Frequency: 1
# Word: heptagonal	Frequency: 1
# Word: awakenings	Frequency: 1
# Word: abagnale	Frequency: 1
# Word: glycosylated	Frequency: 1
# Word: acetabularia	Frequency: 1
# Word: bangia	Frequency: 1
# Word: xylanes	Frequency: 1
# Word: sulfonated	Frequency: 1
# Word: porphyran	Frequency: 1
# Word: furcelleran	Frequency: 1
# Word: funoran	Frequency: 1
# Word: muramic	Frequency: 1
# Word: pentagram	Frequency: 5
# Word: panchamahabhuta	Frequency: 1
# Word: vayu	Frequency: 1
# Word: pavan	Frequency: 1
# Word: pentacles	Frequency: 1
# Word: athame	Frequency: 1
# Word: oreade	Frequency: 1
# Word: dagda	Frequency: 1
# Word: herbalism	Frequency: 1
# Word: cann	Frequency: 1
# Word: baynham	Frequency: 2
# Word: quantick	Frequency: 2
# Word: steeplehammer	Frequency: 1
# Word: shatner	Frequency: 1
# Word: starkly	Frequency: 1
# Word: ekland	Frequency: 1
# Word: darcus	Frequency: 1
# Word: challis	Frequency: 1
# Word: attheraces	Frequency: 4
# Word: trainspotting	Frequency: 1
# Word: coia	Frequency: 1
# Word: teatime	Frequency: 1
# Word: arup	Frequency: 1
# Word: carpar	Frequency: 1
# Word: psittacidae	Frequency: 1
# Word: carolinensis	Frequency: 4
# Word: audobon	Frequency: 1
# Word: traumas	Frequency: 4
# Word: gotlandthe	Frequency: 1
# Word: tarascon	Frequency: 1
# Word: kistvaens	Frequency: 1
# Word: windeatt	Frequency: 1
# Word: dartmore	Frequency: 1
# Word: nakti	Frequency: 1
# Word: noapte	Frequency: 1
# Word: stairno	Frequency: 1
# Word: setare	Frequency: 1
# Word: galakt	Frequency: 1
# Word: ghabh	Frequency: 1
# Word: paronym	Frequency: 1
# Word: retards	Frequency: 1
# Word: preparative	Frequency: 2
# Word: botanischen	Frequency: 1
# Word: precipitational	Frequency: 1
# Word: tography	Frequency: 1
# Word: chromatogram	Frequency: 2
# Word: adsorbent	Frequency: 5
# Word: adaquately	Frequency: 1
# Word: analytes	Frequency: 1
# Word: grafted	Frequency: 1
# Word: novasep	Frequency: 1
# Word: witwatersrand	Frequency: 4
# Word: vilakazi	Frequency: 2
# Word: grammatik	Frequency: 1
# Word: luffa	Frequency: 1
# Word: comparments	Frequency: 1
# Word: centrifugation	Frequency: 2
# Word: canadianisms	Frequency: 1
# Word: hansard	Frequency: 1
# Word: aboot	Frequency: 4
# Word: abawt	Frequency: 1
# Word: abuhwt	Frequency: 1
# Word: michiganders	Frequency: 1
# Word: napkin	Frequency: 1
# Word: leftenant	Frequency: 1
# Word: alcool	Frequency: 1
# Word: alcools	Frequency: 2
# Word: saq	Frequency: 1
# Word: automatiste	Frequency: 1
# Word: lexicographical	Frequency: 1
# Word: raisins	Frequency: 1
# Word: dayliner	Frequency: 1
# Word: eavestroughs	Frequency: 1
# Word: burrard	Frequency: 1
# Word: parkade	Frequency: 1
# Word: percidae	Frequency: 1
# Word: canuck	Frequency: 1
# Word: trawna	Frequency: 1
# Word: hosehead	Frequency: 1
# Word: poohbah	Frequency: 1
# Word: mahsi	Frequency: 1
# Word: masi	Frequency: 1
# Word: maritimer	Frequency: 1
# Word: oat	Frequency: 1
# Word: naht	Frequency: 1
# Word: orillia	Frequency: 1
# Word: twang	Frequency: 2
# Word: identifiably	Frequency: 1
# Word: mcalpine	Frequency: 1
# Word: lali	Frequency: 3
# Word: podstatn	Frequency: 1
# Word: slovka	Frequency: 1
# Word: alina	Frequency: 1
# Word: naproti	Frequency: 1
# Word: dva	Frequency: 4
# Word: locallingo	Frequency: 1
# Word: capsid	Frequency: 4
# Word: chloramphenicol	Frequency: 8
# Word: nitrophenethylacetamide	Frequency: 1
# Word: acetylation	Frequency: 1
# Word: linespacing	Frequency: 1
# Word: grazulis	Frequency: 1
# Word: autom	Frequency: 1
# Word: cagot	Frequency: 1
# Word: kag	Frequency: 1
# Word: creatus	Frequency: 1
# Word: alluvium	Frequency: 1
# Word: execrabilis	Frequency: 1
# Word: adjournment	Frequency: 1
# Word: reformatory	Frequency: 1
# Word: fulmination	Frequency: 1
# Word: decreta	Frequency: 2
# Word: lacensis	Frequency: 1
# Word: diariorum	Frequency: 1
# Word: mansi	Frequency: 1
# Word: waterworth	Frequency: 1
# Word: genuina	Frequency: 1
# Word: historicam	Frequency: 1
# Word: paleotto	Frequency: 1
# Word: actenst	Frequency: 1
# Word: tageb	Frequency: 1
# Word: tridentina	Frequency: 1
# Word: nadph	Frequency: 2
# Word: reticulations	Frequency: 1
# Word: euglenozoa	Frequency: 1
# Word: stroma	Frequency: 2
# Word: catoctin	Frequency: 9
# Word: submarginal	Frequency: 1
# Word: octantis	Frequency: 1
# Word: trishanku	Frequency: 1
# Word: punga	Frequency: 1
# Word: waka	Frequency: 1
# Word: americal	Frequency: 1
# Word: corsali	Frequency: 1
# Word: aethiopia	Frequency: 2
# Word: cassiopea	Frequency: 1
# Word: casiopea	Frequency: 1
# Word: menkar	Frequency: 2
# Word: menkab	Frequency: 1
# Word: mekab	Frequency: 1
# Word: monkar	Frequency: 1
# Word: carinae	Frequency: 1
# Word: bartsch	Frequency: 2
# Word: camelopardis	Frequency: 1
# Word: kanagawa	Frequency: 3
# Word: yaku	Frequency: 2
# Word: hakodate	Frequency: 1
# Word: heliacal	Frequency: 1
# Word: aludra	Frequency: 1
# Word: gomeisa	Frequency: 1
# Word: antecanis	Frequency: 1
# Word: elgomaisa	Frequency: 1
# Word: algomeysa	Frequency: 1
# Word: sagitta	Frequency: 2
# Word: agena	Frequency: 1
# Word: subpages	Frequency: 1
# Word: engelhardt	Frequency: 1
# Word: ejecta	Frequency: 3
# Word: brecciated	Frequency: 2
# Word: iapetus	Frequency: 1
# Word: mahuika	Frequency: 1
# Word: manicouagan	Frequency: 1
# Word: rochechouart	Frequency: 1
# Word: caloris	Frequency: 1
# Word: placemarker	Frequency: 1
# Word: socifacts	Frequency: 1
# Word: leavises	Frequency: 1
# Word: systematicity	Frequency: 1
# Word: tribalisms	Frequency: 1
# Word: romanitas	Frequency: 1
# Word: totowa	Frequency: 1
# Word: vaknin	Frequency: 1
# Word: alphecca	Frequency: 2
# Word: coronae	Frequency: 4
# Word: abell	Frequency: 1
# Word: asteroth	Frequency: 1
# Word: albireo	Frequency: 1
# Word: lyra	Frequency: 2
# Word: waterbird	Frequency: 1
# Word: adige	Frequency: 2
# Word: aridif	Frequency: 1
# Word: azelfafage	Frequency: 1
# Word: ruchba	Frequency: 2
# Word: rukbah	Frequency: 1
# Word: calorimetry	Frequency: 1
# Word: thermochemical	Frequency: 1
# Word: calth	Frequency: 1
# Word: caloriefreak	Frequency: 1
# Word: nutritiondata	Frequency: 1
# Word: calorite	Frequency: 1
# Word: cra	Frequency: 8
# Word: tijuca	Frequency: 1
# Word: ipanema	Frequency: 1
# Word: lage	Frequency: 1
# Word: toshitada	Frequency: 1
# Word: stamper	Frequency: 5
# Word: stampers	Frequency: 2
# Word: laquer	Frequency: 1
# Word: macine	Frequency: 1
# Word: shrinkwrapped	Frequency: 2
# Word: subchannel	Frequency: 3
# Word: parityq	Frequency: 1
# Word: parityp	Frequency: 1
# Word: subchannels	Frequency: 2
# Word: stockham	Frequency: 1
# Word: soundstream	Frequency: 1
# Word: alpert	Frequency: 1
# Word: artemus	Frequency: 5
# Word: caelum	Frequency: 2
# Word: clarinetist	Frequency: 6
# Word: chalumeau	Frequency: 7
# Word: clarinettists	Frequency: 2
# Word: grenadilla	Frequency: 1
# Word: vibrates	Frequency: 1
# Word: vandoren	Frequency: 1
# Word: hyacinthe	Frequency: 2
# Word: rackett	Frequency: 1
# Word: defranco	Frequency: 1
# Word: caillet	Frequency: 1
# Word: transposes	Frequency: 1
# Word: octocontrabass	Frequency: 1
# Word: leblanc	Frequency: 1
# Word: clariperu	Frequency: 1
# Word: skora	Frequency: 1
# Word: legnica	Frequency: 5
# Word: haynow	Frequency: 1
# Word: zlotoryja	Frequency: 1
# Word: chojnowska	Frequency: 1
# Word: chojnowa	Frequency: 1
# Word: paperware	Frequency: 1
# Word: piast	Frequency: 2
# Word: sarna	Frequency: 1
# Word: carnagie	Frequency: 1
# Word: chamaeleontis	Frequency: 3
# Word: mamajek	Frequency: 3
# Word: webda	Frequency: 1
# Word: gallstones	Frequency: 3
# Word: soluable	Frequency: 1
# Word: reductase	Frequency: 5
# Word: pathwaycholesterol	Frequency: 1
# Word: scap	Frequency: 3
# Word: ateries	Frequency: 1
# Word: crystallises	Frequency: 1
# Word: hypocholesterolemia	Frequency: 2
# Word: chiriboga	Frequency: 1
# Word: harmatz	Frequency: 1
# Word: chromatid	Frequency: 2
# Word: tetraploid	Frequency: 1
# Word: karyogram	Frequency: 2
# Word: heterochromatic	Frequency: 1
# Word: unclonable	Frequency: 1
# Word: translocations	Frequency: 1
# Word: aneuploidy	Frequency: 1
# Word: kimballs	Frequency: 1
# Word: chromosomenzahlen	Frequency: 1
# Word: verwandtschaftsverhaltnisse	Frequency: 1
# Word: barberini	Frequency: 4
# Word: macronucleus	Frequency: 2
# Word: membranelles	Frequency: 1
# Word: paroral	Frequency: 1
# Word: infraciliature	Frequency: 2
# Word: ciliophora	Frequency: 1
# Word: choreotrichia	Frequency: 1
# Word: oligotrichia	Frequency: 1
# Word: halteria	Frequency: 1
# Word: hypotrichia	Frequency: 1
# Word: haptoria	Frequency: 1
# Word: trichostomatia	Frequency: 1
# Word: rhynchodia	Frequency: 1
# Word: chonotrichia	Frequency: 1
# Word: podophrya	Frequency: 1
# Word: colpodea	Frequency: 1
# Word: colpoda	Frequency: 1
# Word: prostomatea	Frequency: 1
# Word: oligohymenophorea	Frequency: 1
# Word: astromatia	Frequency: 1
# Word: apostomatia	Frequency: 1
# Word: plagiopylea	Frequency: 1
# Word: sebta	Frequency: 1
# Word: abyla	Frequency: 1
# Word: majkasa	Frequency: 1
# Word: isam	Frequency: 1
# Word: elpida	Frequency: 1
# Word: cigarrette	Frequency: 1
# Word: gametogenic	Frequency: 1
# Word: biochemicals	Frequency: 1
# Word: caroliensis	Frequency: 1
# Word: camoufler	Frequency: 1
# Word: tawny	Frequency: 1
# Word: chromatophores	Frequency: 1
# Word: countershaded	Frequency: 1
# Word: feldgrau	Frequency: 1
# Word: vola	Frequency: 1
# Word: laboratorio	Frequency: 1
# Word: mascheramento	Frequency: 1
# Word: stahlhelme	Frequency: 1
# Word: wardens	Frequency: 1
# Word: tenda	Frequency: 1
# Word: patterning	Frequency: 3
# Word: palmenmuster	Frequency: 1
# Word: restained	Frequency: 1
# Word: veruschka	Frequency: 1
# Word: streetwear	Frequency: 1
# Word: realtree	Frequency: 1
# Word: trialled	Frequency: 1
# Word: kamouflage	Frequency: 1
# Word: throwbacks	Frequency: 1
# Word: atavistic	Frequency: 1
# Word: socialisation	Frequency: 1
# Word: bandura	Frequency: 1
# Word: interactionism	Frequency: 1
# Word: subcultural	Frequency: 4
# Word: hooliganism	Frequency: 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("Iris DataFrame Task") \
    .getOrCreate()

# Read the iris JSON data into a DataFrame
iris_df = spark.read.json("/content/iris.json")

# Calculate Pearson Correlation between petalLength and petalWidth
correlation = iris_df.stat.corr("petalLength", "petalWidth")

print("Pearson Correlation between petalLength and petalWidth:", correlation)

# Show columns sepalLength, sepalWidth, and species for rows where petalLength >= 1.4
filtered_df = iris_df.filter(iris_df["petalLength"] >= 1.4).select("sepalLength", "sepalWidth", "species")
filtered_df.show()

# Stop the SparkSession
spark.stop()
# Out:
# Pearson Correlation between petalLength and petalWidth: 0.9626417223780231
# +-----------+----------+-------+
# |sepalLength|sepalWidth|species|
# +-----------+----------+-------+
# |        5.1|       3.5| setosa|
# |        4.9|       3.0| setosa|
# |        4.6|       3.1| setosa|
# |        5.0|       3.6| setosa|
# |        5.4|       3.9| setosa|
# |        4.6|       3.4| setosa|
# |        5.0|       3.4| setosa|
# |        4.4|       2.9| setosa|
# |        4.9|       3.1| setosa|
# |        5.4|       3.7| setosa|
# |        4.8|       3.4| setosa|
# |        4.8|       3.0| setosa|
# |        5.7|       4.4| setosa|
# |        5.1|       3.5| setosa|
# |        5.7|       3.8| setosa|
# |        5.1|       3.8| setosa|
# |        5.4|       3.4| setosa|
# |        5.1|       3.7| setosa|
# |        5.1|       3.3| setosa|
# |        4.8|       3.4| setosa|
# +-----------+----------+-------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("Iris DataFrame Task") \
    .getOrCreate()

# Read the iris JSON data into a DataFrame
iris_df = spark.read.json("/content/iris.json")

# Show the DataFrame schema
iris_df.printSchema()

# Show the first few rows of the DataFrame
iris_df.show()

# Stop the SparkSession
spark.stop()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- petalLength: double (nullable = true)
#  |-- petalWidth: double (nullable = true)
#  |-- sepalLength: double (nullable = true)
#  |-- sepalWidth: double (nullable = true)
#  |-- species: string (nullable = true)
#
# +---------------+-----------+----------+-----------+----------+-------+
# |_corrupt_record|petalLength|petalWidth|sepalLength|sepalWidth|species|
# +---------------+-----------+----------+-----------+----------+-------+
# |              [|       NULL|      NULL|       NULL|      NULL|   NULL|
# |           NULL|        1.4|       0.2|        5.1|       3.5| setosa|
# |           NULL|        1.4|       0.2|        4.9|       3.0| setosa|
# |           NULL|        1.3|       0.2|        4.7|       3.2| setosa|
# |           NULL|        1.5|       0.2|        4.6|       3.1| setosa|
# |           NULL|        1.4|       0.2|        5.0|       3.6| setosa|
# |           NULL|        1.7|       0.4|        5.4|       3.9| setosa|
# |           NULL|        1.4|       0.3|        4.6|       3.4| setosa|
# |           NULL|        1.5|       0.2|        5.0|       3.4| setosa|
# |           NULL|        1.4|       0.2|        4.4|       2.9| setosa|
# |           NULL|        1.5|       0.1|        4.9|       3.1| setosa|
# |           NULL|        1.5|       0.2|        5.4|       3.7| setosa|
# |           NULL|        1.6|       0.2|        4.8|       3.4| setosa|
# |           NULL|        1.4|       0.1|        4.8|       3.0| setosa|
# |           NULL|        1.1|       0.1|        4.3|       3.0| setosa|
# |           NULL|        1.2|       0.2|        5.8|       4.0| setosa|
# |           NULL|        1.5|       0.4|        5.7|       4.4| setosa|
# |           NULL|        1.3|       0.4|        5.4|       3.9| setosa|
# |           NULL|        1.4|       0.3|        5.1|       3.5| setosa|
# |           NULL|        1.7|       0.3|        5.7|       3.8| setosa|
# +---------------+-----------+----------+-----------+----------+-------+
# only showing top 20 rows
